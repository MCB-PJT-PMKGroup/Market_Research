# %%
# pip install pandas openyxl psycopg2 sqlalchemy

import pandas as pd
from sqlalchemy import create_engine

# %%
excel_file = 'K7 담배데이터_23년 07월.csv'
df = pd.read_csv(excel_file, encoding='utf-8') 

# 데이터베이스 연결 문자열
database_url = 'postgresql://postgres:postgres@localhost/cx'
# SQLAlchemy 엔진 생성
engine = create_engine(database_url)

df.to_sql('table_name', engine, index=False, if_exists='append')

df
# Out:
#             de_dt                                            rct_seq channel  \
# 0        20230701  00023CB3671F88210F01D8D65C653F24D06E59DE7B6D37...      K7
# 1        20230701  0002D54D870D08876F325A7F5CF3478A9A8EACF9624859...      K7
# 2        20230701  00062B68E68845E32A9035B4024DDA574B1D35D1FE6253...      K7
# 3        20230701  000789C8211106AA86C3C3B2D17897BBC3DEF6A2AD47DB...      K7
# 4        20230701  00083150A874890E740FBE173AA007E0C63F7B197EFB42...      K7
# ...           ...                                                ...     ...
# 1020235  20230731  FFEF831D21E25B86E5F552C6B98BEE74705163DA6C3EA5...      K7
# 1020236  20230731  FFF159A51E092D12151E4C207EF40586C6B899350DD293...      K7
# 1020237  20230731  FFFBFE94BF273A990E92ECEC772E34FA559EE93B995FAA...      K7
# 1020238  20230731  FFFE662DD53555D7487A93E21CDD35FD9DD44083795B27...      K7
# 1020239  20230731  FFFE662DD53555D7487A93E21CDD35FD9DD44083795B27...      K7
#
#         h_cate m_cate        s_cate product_mnft        product_name  \
# 0           담배   일반담배          수입담배         옥산유통        P)팔리아멘트하이브리드
# 1           담배   전자담배       전자담배용리필      한국필립모리스            P)테리아 블루
# 2           담배   일반담배          수입담배         옥산유통         P)팔리아멘트아쿠아5
# 3           담배   일반담배          수입담배         옥산유통       P)말보로아이스블라스트원
# 4           담배   일반담배          국산담배        케이티앤지          K)에쎄체인지1mg
# ...        ...    ...           ...          ...                 ...
# 1020235     담배   일반담배          국산담배        케이티앤지         K)보헴시가미니5mg
# 1020236     담배   전자담배       전자담배용리필      한국필립모리스         P)테리아 블랙옐로우
# 1020237     담배   전자담배       전자담배용리필      한국필립모리스            P)테리아 실버
# 1020238     담배   일반담배          국산담배        케이티앤지  K)MIIX 믹스(릴 하이브리드)
# 1020239     담배   전자담배  전자담배용기기/악세서리        케이티앤지        K)MIIX 아이스더블
#
#           product_code  buy_ct  buy_am  buy_se  buy_dc gender  age  \
# 0             88017693       1    4500    4500       0      남  50대
# 1             88023014       2    9600    9600       0      남  40대
# 2             88013121       1    4500    4500       0      남  30대
# 3             88017617       1    4500    4500       0      여  20대
# 4        8801116005314       1    4500    4500       0      남  50대
# ...                ...     ...     ...     ...     ...    ...  ...
# 1020235  8801116004676       1    4500    4500       0      남  40대
# 1020236       88023595       1    4800    4800       0      남  30대
# 1020237       88023052       1    4800    4800       0      남  40대
# 1020238  8801116012435       1    4500    4500       0      여  20대
# 1020239  8801116013234       1    4500    4500       0      여  20대
#
#                                                         id
# 0        D9B83641AB74E12A249072697985A055DD2664A8D96ABA...
# 1        1720991A16D073BBD97CCF5ABA50C978041465970E624B...
# 2        A1584B58463D1F8C9719F41C66E9F08CF371B2FBA5392B...
# 3        D42B2BF36BEB0D872C18D5383B96F07E768A869669B6AB...
# 4        3A728E07DE382200235A5FEBE036ECD2A1572920DF0CA2...
# ...                                                    ...
# 1020235  F16A264745919A902607B9774AD9D077EC45E1BE730250...
# 1020236  D27DBCA08F61AE1B2398BF8B62955B003887B93DB576DE...
# 1020237  1900ADA14C43D1A7E3959C4376428D2EA700438872B573...
# 1020238  396210F9C796F1A3F45B39520D604649602E9610BB4A7D...
# 1020239  396210F9C796F1A3F45B39520D604649602E9610BB4A7D...
#
# [1020240 rows x 16 columns]
